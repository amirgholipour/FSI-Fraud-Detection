# %% [markdown]
# ## Flask
# Our API will be served directly from our container using Flask, a popular Python Web Server.
# The Flask application, which will call our prediction function, is defined in the `wsgi.py` file.

# %% [markdown]
# As always, we'll first run some imports to make sure all our requirements are there:

# %%
import os
os.system('ls')
# Out:
# 03_FraudDetection_run_application.ipynb
# 04_FraudDetection_test_application.ipynb
# data
# docs
# gunicorn_config.py
# __init__.py
# LICENSE
# Makefile
# models
# notebooks
# Pipfile
# prediction.py
# README.md
# references
# reports
# requirements.txt
# setup.py
# src
# test_environment.py
# tox.ini
# Untitled.ipynb
# wsgi.py
# 0

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Obtaining file:///opt/app-root/src/FSI-Fraud-Detection-Workshop (from -r requirements.txt (line 2))
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (8.0.3)
# Requirement already satisfied: Sphinx in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (4.5.0)
# Requirement already satisfied: coverage in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (6.2)
# Requirement already satisfied: awscli in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (1.20.65)
# Requirement already satisfied: flake8 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (3.8.4)
# Requirement already satisfied: python-dotenv>=0.5.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.20.0)
# Requirement already satisfied: joblib==1.1.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: bcrypt==3.2.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (3.2.0)
# Requirement already satisfied: defusedxml==0.7.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (0.7.1)
# Requirement already satisfied: Pillow>=9.0.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (9.1.0)
# Requirement already satisfied: pyopenssl==20.0.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (20.0.1)
# Requirement already satisfied: scipy==1.7.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (1.7.1)
# Requirement already satisfied: scikit-learn==1.0.2 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (1.0.2)
# Requirement already satisfied: tensorflow==2.8.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (2.8.0)
# Requirement already satisfied: keras==2.8.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 19)) (2.8.0)
# Requirement already satisfied: cffi>=1.1 in /opt/app-root/lib/python3.8/site-packages (from bcrypt==3.2.0->-r requirements.txt (line 12)) (1.15.0)
# Requirement already satisfied: six>=1.4.1 in /opt/app-root/lib/python3.8/site-packages (from bcrypt==3.2.0->-r requirements.txt (line 12)) (1.16.0)
# Requirement already satisfied: cryptography>=3.2 in /opt/app-root/lib/python3.8/site-packages (from pyopenssl==20.0.1->-r requirements.txt (line 15)) (3.4.8)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /opt/app-root/lib/python3.8/site-packages (from scipy==1.7.1->-r requirements.txt (line 16)) (1.22.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn==1.0.2->-r requirements.txt (line 17)) (3.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (0.2.0)
# Requirement already satisfied: gast>=0.2.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (0.4.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (2.8.0.dev2021122109)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (0.23.1)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (4.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (1.12.1)
# Requirement already satisfied: libclang>=9.0.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (12.0.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (1.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (1.1.2)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (60.9.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (1.43.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (2.10.0)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (3.19.3)
# Requirement already satisfied: flatbuffers>=1.12 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.8.0->-r requirements.txt (line 18)) (1.12)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (21.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (4.10.0)
# Requirement already satisfied: Jinja2>=2.3 in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (2.11.3)
# Requirement already satisfied: docutils<0.18,>=0.14 in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (0.15.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (1.1.5)
# Requirement already satisfied: sphinxcontrib-devhelp in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (1.0.2)
# Requirement already satisfied: imagesize in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: sphinxcontrib-qthelp in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (1.0.3)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (0.7.12)
# Requirement already satisfied: Pygments>=2.0 in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (2.11.2)
# Requirement already satisfied: snowballstemmer>=1.1 in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: requests>=2.5.0 in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (2.27.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: babel>=1.3 in /opt/app-root/lib/python3.8/site-packages (from Sphinx->-r requirements.txt (line 6)) (2.9.1)
# Requirement already satisfied: botocore==1.21.65 in /opt/app-root/lib/python3.8/site-packages (from awscli->-r requirements.txt (line 8)) (1.21.65)
# Requirement already satisfied: colorama<0.4.4,>=0.2.5 in /opt/app-root/lib/python3.8/site-packages (from awscli->-r requirements.txt (line 8)) (0.4.3)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /opt/app-root/lib/python3.8/site-packages (from awscli->-r requirements.txt (line 8)) (4.7.2)
# Requirement already satisfied: PyYAML<5.5,>=3.10 in /opt/app-root/lib/python3.8/site-packages (from awscli->-r requirements.txt (line 8)) (5.4.1)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /opt/app-root/lib/python3.8/site-packages (from awscli->-r requirements.txt (line 8)) (0.5.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/app-root/lib/python3.8/site-packages (from botocore==1.21.65->awscli->-r requirements.txt (line 8)) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/app-root/lib/python3.8/site-packages (from botocore==1.21.65->awscli->-r requirements.txt (line 8)) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/app-root/lib/python3.8/site-packages (from botocore==1.21.65->awscli->-r requirements.txt (line 8)) (1.26.5)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /opt/app-root/lib/python3.8/site-packages (from flake8->-r requirements.txt (line 9)) (0.6.1)
# Requirement already satisfied: pyflakes<2.3.0,>=2.2.0 in /opt/app-root/lib/python3.8/site-packages (from flake8->-r requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: pycodestyle<2.7.0,>=2.6.0a1 in /opt/app-root/lib/python3.8/site-packages (from flake8->-r requirements.txt (line 9)) (2.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/app-root/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow==2.8.0->-r requirements.txt (line 18)) (0.37.1)
# Requirement already satisfied: pytz>=2015.7 in /opt/app-root/lib/python3.8/site-packages (from babel>=1.3->Sphinx->-r requirements.txt (line 6)) (2021.3)
# Requirement already satisfied: pycparser in /opt/app-root/lib/python3.8/site-packages (from cffi>=1.1->bcrypt==3.2.0->-r requirements.txt (line 12)) (2.21)
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.8/site-packages (from importlib-metadata>=4.4->Sphinx->-r requirements.txt (line 6)) (3.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/app-root/lib/python3.8/site-packages (from Jinja2>=2.3->Sphinx->-r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.5.0->Sphinx->-r requirements.txt (line 6)) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.5.0->Sphinx->-r requirements.txt (line 6)) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from requests>=2.5.0->Sphinx->-r requirements.txt (line 6)) (2.0.10)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/app-root/lib/python3.8/site-packages (from rsa<4.8,>=3.1.2->awscli->-r requirements.txt (line 8)) (0.4.8)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->-r requirements.txt (line 18)) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->-r requirements.txt (line 18)) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->-r requirements.txt (line 18)) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->-r requirements.txt (line 18)) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->-r requirements.txt (line 18)) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/app-root/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->-r requirements.txt (line 18)) (3.3.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/app-root/lib/python3.8/site-packages (from packaging->Sphinx->-r requirements.txt (line 6)) (3.0.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/app-root/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->-r requirements.txt (line 18)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->-r requirements.txt (line 18)) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/app-root/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0->-r requirements.txt (line 18)) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/app-root/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0->-r requirements.txt (line 18)) (3.1.1)
# Installing collected packages: src
#   Attempting uninstall: src
#     Found existing installation: src 0.1.0
#     Uninstalling src-0.1.0:
#       Successfully uninstalled src-0.1.0
#   Running setup.py develop for src
# Successfully installed src-0.1.0

# %% [markdown]
# Now that we have everything in place, we can launch the Flask application.
#
# (Please ignore the CUDA errors of warning if you don't have any GPU).
#
# This cell will be in a **permanent running state**. That's normal as the webserver process will keep running. When you are **finished** with the test you can just select the cell, and click on the **Stop button** (next to Run).

# %%
# !FLASK_ENV=development FLASK_APP=wsgi.py flask run
# Out:
#  * Serving Flask app "wsgi.py" (lazy loading)
#  * Environment: development
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 122-592-528
# Loading model 808
# Loaded model
# Models have just loaded!!!!
# Loading model 842
# Loaded model
# Models have just loaded!!!!
# 127.0.0.1 - - [03/Apr/2022 07:57:05] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/json/decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# StopIteration: 9
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2450, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1867, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/wsgi.py", line 16, in object_detection
#     body = json.loads(data)
#   File "/usr/lib64/python3.8/json/__init__.py", line 357, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib64/python3.8/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib64/python3.8/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 2 column 1 (char 9)
# Step1: Loading models
# [77627, -7.139060068, 2.773081604, -6.757845069, 4.446455974, -5.464428185, -1.713401451, -6.485365409, 3.409394799, -3.053492714, -6.260705515, 2.394167666, -6.16353738, 0.602850521, -5.606346429, 0.206621734, -6.52508104, -11.40836754, -4.693977736, 2.431274492, -0.616949301, 1.303250309, -0.016118152, -0.876669888, 0.382229801, -1.054623888, -0.614606037, -0.766848112, 0.409423944, 106.9]
# Step1 finished!!!!
# Step2: Scaled the input data.
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [[ -0.36191958  -3.64480926   1.67932663  -4.45693957   3.14044952
#    -3.95902967  -1.28607794  -5.24243016   2.85460083  -2.77936363
#    -5.7498442    2.34558765  -6.16847441   0.60571404  -5.84851026
#     0.22573854  -7.44658601 -13.43210847  -5.60023766   2.98668034
#    -0.80027287   1.77428181  -0.02221048  -1.40388658   0.63111091
#    -2.02315386  -1.27451822  -1.89987047   1.24036783   0.07416602]]
# Step2 finished!!!!
# Step3:  Perform prediction!!!
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Step3 finished!!!!
# 1
# Predicted Class name:  Fraud
# 127.0.0.1 - - [03/Apr/2022 07:58:01] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2450, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1867, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/wsgi.py", line 17, in object_detection
#     return jsonify(predict(body))
#   File "/opt/app-root/lib/python3.8/site-packages/flask/json/__init__.py", line 370, in jsonify
#     dumps(data, indent=indent, separators=separators) + "\n",
#   File "/opt/app-root/lib/python3.8/site-packages/flask/json/__init__.py", line 211, in dumps
#     rv = _json.dumps(obj, **kwargs)
#   File "/usr/lib64/python3.8/json/__init__.py", line 234, in dumps
#     return cls(
#   File "/usr/lib64/python3.8/json/encoder.py", line 201, in encode
#     chunks = list(chunks)
#   File "/usr/lib64/python3.8/json/encoder.py", line 431, in _iterencode
#     yield from _iterencode_dict(o, _current_indent_level)
#   File "/usr/lib64/python3.8/json/encoder.py", line 405, in _iterencode_dict
#     yield from chunks
#   File "/usr/lib64/python3.8/json/encoder.py", line 438, in _iterencode
#     o = _default(o)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/json/__init__.py", line 100, in default
#     return _json.JSONEncoder.default(self, o)
#   File "/usr/lib64/python3.8/json/encoder.py", line 179, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type ndarray is not JSON serializable
# Step1: Loading models
# [77627, -7.139060068, 2.773081604, -6.757845069, 4.446455974, -5.464428185, -1.713401451, -6.485365409, 3.409394799, -3.053492714, -6.260705515, 2.394167666, -6.16353738, 0.602850521, -5.606346429, 0.206621734, -6.52508104, -11.40836754, -4.693977736, 2.431274492, -0.616949301, 1.303250309, -0.016118152, -0.876669888, 0.382229801, -1.054623888, -0.614606037, -0.766848112, 0.409423944, 106.9]
# Step1 finished!!!!
# Step2: Scaled the input data.
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [[ -0.36191958  -3.64480926   1.67932663  -4.45693957   3.14044952
#    -3.95902967  -1.28607794  -5.24243016   2.85460083  -2.77936363
#    -5.7498442    2.34558765  -6.16847441   0.60571404  -5.84851026
#     0.22573854  -7.44658601 -13.43210847  -5.60023766   2.98668034
#    -0.80027287   1.77428181  -0.02221048  -1.40388658   0.63111091
#    -2.02315386  -1.27451822  -1.89987047   1.24036783   0.07416602]]
# Step2 finished!!!!
# Step3:  Perform prediction!!!
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Step3 finished!!!!
# 1
# Predicted Class name:  Fraud
# 127.0.0.1 - - [03/Apr/2022 07:58:10] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2450, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1867, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/wsgi.py", line 17, in object_detection
#     return jsonify(predict(body))
#   File "/opt/app-root/lib/python3.8/site-packages/flask/json/__init__.py", line 370, in jsonify
#     dumps(data, indent=indent, separators=separators) + "\n",
#   File "/opt/app-root/lib/python3.8/site-packages/flask/json/__init__.py", line 211, in dumps
#     rv = _json.dumps(obj, **kwargs)
#   File "/usr/lib64/python3.8/json/__init__.py", line 234, in dumps
#     return cls(
#   File "/usr/lib64/python3.8/json/encoder.py", line 201, in encode
#     chunks = list(chunks)
#   File "/usr/lib64/python3.8/json/encoder.py", line 431, in _iterencode
#     yield from _iterencode_dict(o, _current_indent_level)
#   File "/usr/lib64/python3.8/json/encoder.py", line 405, in _iterencode_dict
#     yield from chunks
#   File "/usr/lib64/python3.8/json/encoder.py", line 438, in _iterencode
#     o = _default(o)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/json/__init__.py", line 100, in default
#     return _json.JSONEncoder.default(self, o)
#   File "/usr/lib64/python3.8/json/encoder.py", line 179, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type ndarray is not JSON serializable
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 122-592-528
# Loading model 1035
# Loaded model
# Models have just loaded!!!!
# Step1: Loading models
# [77627, -7.139060068, 2.773081604, -6.757845069, 4.446455974, -5.464428185, -1.713401451, -6.485365409, 3.409394799, -3.053492714, -6.260705515, 2.394167666, -6.16353738, 0.602850521, -5.606346429, 0.206621734, -6.52508104, -11.40836754, -4.693977736, 2.431274492, -0.616949301, 1.303250309, -0.016118152, -0.876669888, 0.382229801, -1.054623888, -0.614606037, -0.766848112, 0.409423944, 106.9]
# Step1 finished!!!!
# Step2: Scaled the input data.
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [03/Apr/2022 07:59:47] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2450, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1867, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/wsgi.py", line 17, in object_detection
#     return jsonify(predict(body))
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py", line 37, in predict
#     model_ready_input = scaler.transform([X])
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/preprocessing/_data.py", line 973, in transform
#     X = self._validate_data(
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/base.py", line 566, in _validate_data
#     X = check_array(X, **check_params)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/utils/validation.py", line 746, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
# TypeError: float() argument must be a string or a number, not 'dict'
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 122-592-528
# Loading model 1125
# Loaded model
# Models have just loaded!!!!
# Step1: Loading models
# Step1 finished!!!!
# Step2: Scaled the input data.
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [03/Apr/2022 08:00:41] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2450, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1867, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/wsgi.py", line 17, in object_detection
#     return jsonify(predict(body))
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py", line 37, in predict
#     model_ready_input = scaler.transform([X])
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/preprocessing/_data.py", line 973, in transform
#     X = self._validate_data(
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/base.py", line 566, in _validate_data
#     X = check_array(X, **check_params)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/utils/validation.py", line 746, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
# TypeError: float() argument must be a string or a number, not 'dict'
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 122-592-528
# Loading model 1251
# Loaded model
# Models have just loaded!!!!
# Step1: Loading models
# [77627, -7.139060068, 2.773081604, -6.757845069, 4.446455974, -5.464428185, -1.713401451, -6.485365409, 3.409394799, -3.053492714, -6.260705515, 2.394167666, -6.16353738, 0.602850521, -5.606346429, 0.206621734, -6.52508104, -11.40836754, -4.693977736, 2.431274492, -0.616949301, 1.303250309, -0.016118152, -0.876669888, 0.382229801, -1.054623888, -0.614606037, -0.766848112, 0.409423944, 106.9]
# <class 'list'>
# Step1 finished!!!!
# Step2: Scaled the input data.
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [[ -0.36191958  -3.64480926   1.67932663  -4.45693957   3.14044952
#    -3.95902967  -1.28607794  -5.24243016   2.85460083  -2.77936363
#    -5.7498442    2.34558765  -6.16847441   0.60571404  -5.84851026
#     0.22573854  -7.44658601 -13.43210847  -5.60023766   2.98668034
#    -0.80027287   1.77428181  -0.02221048  -1.40388658   0.63111091
#    -2.02315386  -1.27451822  -1.89987047   1.24036783   0.07416602]]
# Step2 finished!!!!
# Step3:  Perform prediction!!!
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Step3 finished!!!!
# 1
# Predicted Class name:  Fraud
# 127.0.0.1 - - [03/Apr/2022 08:02:31] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2450, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1867, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/wsgi.py", line 17, in object_detection
#     return jsonify(predict(body))
#   File "/opt/app-root/lib/python3.8/site-packages/flask/json/__init__.py", line 370, in jsonify
#     dumps(data, indent=indent, separators=separators) + "\n",
#   File "/opt/app-root/lib/python3.8/site-packages/flask/json/__init__.py", line 211, in dumps
#     rv = _json.dumps(obj, **kwargs)
#   File "/usr/lib64/python3.8/json/__init__.py", line 234, in dumps
#     return cls(
#   File "/usr/lib64/python3.8/json/encoder.py", line 201, in encode
#     chunks = list(chunks)
#   File "/usr/lib64/python3.8/json/encoder.py", line 431, in _iterencode
#     yield from _iterencode_dict(o, _current_indent_level)
#   File "/usr/lib64/python3.8/json/encoder.py", line 405, in _iterencode_dict
#     yield from chunks
#   File "/usr/lib64/python3.8/json/encoder.py", line 438, in _iterencode
#     o = _default(o)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/json/__init__.py", line 100, in default
#     return _json.JSONEncoder.default(self, o)
#   File "/usr/lib64/python3.8/json/encoder.py", line 179, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type ndarray is not JSON serializable
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 122-592-528
# Loading model 1395
# Loaded model
# Models have just loaded!!!!
# Step1: Loading models
# [77627, -7.139060068, 2.773081604, -6.757845069, 4.446455974, -5.464428185, -1.713401451, -6.485365409, 3.409394799, -3.053492714, -6.260705515, 2.394167666, -6.16353738, 0.602850521, -5.606346429, 0.206621734, -6.52508104, -11.40836754, -4.693977736, 2.431274492, -0.616949301, 1.303250309, -0.016118152, -0.876669888, 0.382229801, -1.054623888, -0.614606037, -0.766848112, 0.409423944, 106.9]
# <class 'list'>
# Step1 finished!!!!
# Step2: Scaled the input data.
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [03/Apr/2022 08:03:38] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2450, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1867, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/wsgi.py", line 17, in object_detection
#     return jsonify(predict(body))
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py", line 38, in predict
#     model_ready_input = scaler.transform(np.array(X['data']))
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/preprocessing/_data.py", line 973, in transform
#     X = self._validate_data(
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/base.py", line 566, in _validate_data
#     X = check_array(X, **check_params)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/utils/validation.py", line 769, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 7.76270000e+04 -7.13906007e+00  2.77308160e+00 -6.75784507e+00
#   4.44645597e+00 -5.46442819e+00 -1.71340145e+00 -6.48536541e+00
#   3.40939480e+00 -3.05349271e+00 -6.26070551e+00  2.39416767e+00
#  -6.16353738e+00  6.02850521e-01 -5.60634643e+00  2.06621734e-01
#  -6.52508104e+00 -1.14083675e+01 -4.69397774e+00  2.43127449e+00
#  -6.16949301e-01  1.30325031e+00 -1.61181520e-02 -8.76669888e-01
#   3.82229801e-01 -1.05462389e+00 -6.14606037e-01 -7.66848112e-01
#   4.09423944e-01  1.06900000e+02].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 122-592-528
# Loading model 1492
# Loaded model
# Models have just loaded!!!!
# Step1: Loading models
# [77627, -7.139060068, 2.773081604, -6.757845069, 4.446455974, -5.464428185, -1.713401451, -6.485365409, 3.409394799, -3.053492714, -6.260705515, 2.394167666, -6.16353738, 0.602850521, -5.606346429, 0.206621734, -6.52508104, -11.40836754, -4.693977736, 2.431274492, -0.616949301, 1.303250309, -0.016118152, -0.876669888, 0.382229801, -1.054623888, -0.614606037, -0.766848112, 0.409423944, 106.9]
# <class 'list'>
# Step1 finished!!!!
# Step2: Scaled the input data.
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [03/Apr/2022 08:04:19] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2450, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1867, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/wsgi.py", line 17, in object_detection
#     return jsonify(predict(body))
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py", line 38, in predict
#     model_ready_input = scaler.transform(X['data'])
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/preprocessing/_data.py", line 973, in transform
#     X = self._validate_data(
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/base.py", line 566, in _validate_data
#     X = check_array(X, **check_params)
#   File "/opt/app-root/lib/python3.8/site-packages/sklearn/utils/validation.py", line 769, in check_array
#     raise ValueError(
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 7.76270000e+04 -7.13906007e+00  2.77308160e+00 -6.75784507e+00
#   4.44645597e+00 -5.46442819e+00 -1.71340145e+00 -6.48536541e+00
#   3.40939480e+00 -3.05349271e+00 -6.26070551e+00  2.39416767e+00
#  -6.16353738e+00  6.02850521e-01 -5.60634643e+00  2.06621734e-01
#  -6.52508104e+00 -1.14083675e+01 -4.69397774e+00  2.43127449e+00
#  -6.16949301e-01  1.30325031e+00 -1.61181520e-02 -8.76669888e-01
#   3.82229801e-01 -1.05462389e+00 -6.14606037e-01 -7.66848112e-01
#   4.09423944e-01  1.06900000e+02].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 122-592-528
# Loading model 1578
# Loaded model
# Models have just loaded!!!!
# Step1: Loading models
# [77627, -7.139060068, 2.773081604, -6.757845069, 4.446455974, -5.464428185, -1.713401451, -6.485365409, 3.409394799, -3.053492714, -6.260705515, 2.394167666, -6.16353738, 0.602850521, -5.606346429, 0.206621734, -6.52508104, -11.40836754, -4.693977736, 2.431274492, -0.616949301, 1.303250309, -0.016118152, -0.876669888, 0.382229801, -1.054623888, -0.614606037, -0.766848112, 0.409423944, 106.9]
# <class 'list'>
# Step1 finished!!!!
# Step2: Scaled the input data.
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [[ -0.36191958  -3.64480926   1.67932663  -4.45693957   3.14044952
#    -3.95902967  -1.28607794  -5.24243016   2.85460083  -2.77936363
#    -5.7498442    2.34558765  -6.16847441   0.60571404  -5.84851026
#     0.22573854  -7.44658601 -13.43210847  -5.60023766   2.98668034
#    -0.80027287   1.77428181  -0.02221048  -1.40388658   0.63111091
#    -2.02315386  -1.27451822  -1.89987047   1.24036783   0.07416602]]
# Step2 finished!!!!
# Step3:  Perform prediction!!!
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Step3 finished!!!!
# 1
# Predicted Class name:  Fraud
# 127.0.0.1 - - [03/Apr/2022 08:04:53] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2450, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1867, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/wsgi.py", line 17, in object_detection
#     return jsonify(predict(body))
#   File "/opt/app-root/lib/python3.8/site-packages/flask/json/__init__.py", line 370, in jsonify
#     dumps(data, indent=indent, separators=separators) + "\n",
#   File "/opt/app-root/lib/python3.8/site-packages/flask/json/__init__.py", line 211, in dumps
#     rv = _json.dumps(obj, **kwargs)
#   File "/usr/lib64/python3.8/json/__init__.py", line 234, in dumps
#     return cls(
#   File "/usr/lib64/python3.8/json/encoder.py", line 201, in encode
#     chunks = list(chunks)
#   File "/usr/lib64/python3.8/json/encoder.py", line 431, in _iterencode
#     yield from _iterencode_dict(o, _current_indent_level)
#   File "/usr/lib64/python3.8/json/encoder.py", line 405, in _iterencode_dict
#     yield from chunks
#   File "/usr/lib64/python3.8/json/encoder.py", line 438, in _iterencode
#     o = _default(o)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/json/__init__.py", line 100, in default
#     return _json.JSONEncoder.default(self, o)
#   File "/usr/lib64/python3.8/json/encoder.py", line 179, in default
#     raise TypeError(f'Object of type {o.__class__.__name__} '
# TypeError: Object of type ndarray is not JSON serializable
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 122-592-528
# Loading model 1672
# Loaded model
# Models have just loaded!!!!
# Step1: Loading models
# [77627, -7.139060068, 2.773081604, -6.757845069, 4.446455974, -5.464428185, -1.713401451, -6.485365409, 3.409394799, -3.053492714, -6.260705515, 2.394167666, -6.16353738, 0.602850521, -5.606346429, 0.206621734, -6.52508104, -11.40836754, -4.693977736, 2.431274492, -0.616949301, 1.303250309, -0.016118152, -0.876669888, 0.382229801, -1.054623888, -0.614606037, -0.766848112, 0.409423944, 106.9]
# <class 'list'>
# Step1 finished!!!!
# Step2: Scaled the input data.
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [[ -0.36191958  -3.64480926   1.67932663  -4.45693957   3.14044952
#    -3.95902967  -1.28607794  -5.24243016   2.85460083  -2.77936363
#    -5.7498442    2.34558765  -6.16847441   0.60571404  -5.84851026
#     0.22573854  -7.44658601 -13.43210847  -5.60023766   2.98668034
#    -0.80027287   1.77428181  -0.02221048  -1.40388658   0.63111091
#    -2.02315386  -1.27451822  -1.89987047   1.24036783   0.07416602]]
# Step2 finished!!!!
# Step3:  Perform prediction!!!
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Step3 finished!!!!
# 1
# Predicted Class name:  Fraud
# 127.0.0.1 - - [03/Apr/2022 08:06:30] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2450, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1867, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/wsgi.py", line 17, in object_detection
#     return jsonify(predict(body))
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py", line 59, in predict
#     json_results = {"Predicted value": str(predicted_class).tolist(),"Predicted Class Label": pred_label.tolist(),"Predicted Class Probability": pred_prob.tolist()}
# AttributeError: 'str' object has no attribute 'tolist'
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.ipynb_checkpoints/prediction-checkpoint.py', reloading
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 122-592-528
# Loading model 1756
# Loaded model
# Models have just loaded!!!!
# Step1: Loading models
# [77627, -7.139060068, 2.773081604, -6.757845069, 4.446455974, -5.464428185, -1.713401451, -6.485365409, 3.409394799, -3.053492714, -6.260705515, 2.394167666, -6.16353738, 0.602850521, -5.606346429, 0.206621734, -6.52508104, -11.40836754, -4.693977736, 2.431274492, -0.616949301, 1.303250309, -0.016118152, -0.876669888, 0.382229801, -1.054623888, -0.614606037, -0.766848112, 0.409423944, 106.9]
# <class 'list'>
# Step1 finished!!!!
# Step2: Scaled the input data.
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [[ -0.36191958  -3.64480926   1.67932663  -4.45693957   3.14044952
#    -3.95902967  -1.28607794  -5.24243016   2.85460083  -2.77936363
#    -5.7498442    2.34558765  -6.16847441   0.60571404  -5.84851026
#     0.22573854  -7.44658601 -13.43210847  -5.60023766   2.98668034
#    -0.80027287   1.77428181  -0.02221048  -1.40388658   0.63111091
#    -2.02315386  -1.27451822  -1.89987047   1.24036783   0.07416602]]
# Step2 finished!!!!
# Step3:  Perform prediction!!!
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /opt/app-root/lib64/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Step3 finished!!!!
# 1
# Predicted Class name:  Fraud
# 127.0.0.1 - - [03/Apr/2022 08:06:54] "POST /predictions HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2464, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2450, in wsgi_app
#     response = self.handle_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1867, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/app-root/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/app-root/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/wsgi.py", line 17, in object_detection
#     return jsonify(predict(body))
#   File "/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py", line 59, in predict
#     json_results = {"Predicted value": str(predicted_class),"Predicted Class Label": pred_label.tolist(),"Predicted Class Probability": pred_prob.tolist()}
# AttributeError: 'str' object has no attribute 'tolist'
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/prediction.py', reloading
#  * Detected change in '/opt/app-root/src/FSI-Fraud-Detection-Workshop/.~prediction.py', reloading
# ...
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/translate/wmt_t2t.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/translate/wmt_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/bair_robot_pushing.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/bair_robot_pushing_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/moving_mnist.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/moving_sequence.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/bair_robot_pushing.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/bair_robot_pushing.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/bair_robot_pushing.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/bair_robot_pushing_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/bair_robot_pushing_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/bair_robot_pushing_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/moving_mnist.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/moving_mnist.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/moving_mnist.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/moving_sequence.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/moving_sequence.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/moving_sequence.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/moving_sequence_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/moving_sequence_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/moving_sequence_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/robonet.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/robonet.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/robonet.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/robonet_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/robonet_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/robonet_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/bair_robot_pushing.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/bair_robot_pushing_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/moving_mnist.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/moving_sequence.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/moving_sequence_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/moving_sequence.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/moving_sequence.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/moving_sequence_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/moving_sequence_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/moving_sequence_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/robonet.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/robonet.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/robonet.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/robonet_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/robonet_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/robonet_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/starcraft.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/starcraft.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/starcraft.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/starcraft_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/starcraft_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/starcraft_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/ucf101.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/ucf101.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/ucf101.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/ucf101_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/ucf101_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/ucf101_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/starcraft.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/starcraft.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/starcraft.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/starcraft_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/starcraft_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/starcraft_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/ucf101.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/ucf101.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/ucf101.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/ucf101_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/ucf101_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/ucf101_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/davis/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/davis/davis.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/davis/davis_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/davis/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/davis/davis.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/davis/davis_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/tao/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/tao/tao.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/tao/tao_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/davis/davis_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/davis/davis_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/davis/davis_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/tao/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/tao/tao.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/tao/tao_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/youtube_vis/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/youtube_vis/youtube_vis.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/video/youtube_vis/youtube_vis_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/gref/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/gref/gref.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/gref/gref_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/grounded_scan/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/grounded_scan/grounded_scan.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/grounded_scan/grounded_scan_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/refcoco/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/refcoco/manual_download_process.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/refcoco/refcoco.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/refcoco/refcoco_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/youtube_vis/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/youtube_vis/youtube_vis.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/video/youtube_vis/youtube_vis_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/gref/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/gref/gref.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/gref/gref_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/grounded_scan/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/grounded_scan/grounded_scan.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/grounded_scan/grounded_scan_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/refcoco/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/refcoco/manual_download_process.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/refcoco/refcoco.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/refcoco/refcoco_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/wit/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/wit/wit.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/wit/wit_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/wit/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/wit/wit.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/wit/wit_test.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/wit_kaggle/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/wit_kaggle/wit_kaggle.py', reloading
#  * Detected change in '/opt/app-root/lib/python3.8/site-packages/tensorflow_datasets/vision_language/wit_kaggle/wit_kaggle_test.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/wit_kaggle/__init__.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/wit_kaggle/wit_kaggle.py', reloading
#  * Detected change in '/opt/app-root/lib64/python3.8/site-packages/tensorflow_datasets/vision_language/wit_kaggle/wit_kaggle_test.py', reloading
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 122-592-528
# Loading model 2323

# %% [markdown]
# Once the models have been loaded, our server is ready to take requests. Leave this notebook running,and open `04_FraudDetection_test_application.ipynb`.
